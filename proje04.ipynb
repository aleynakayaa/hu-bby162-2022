# %% [markdown]
# <a href="https://colab.research.google.com/github/aleynakayaa/hu-bby162-2022/blob/main/proje04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')


dosyaGidis = "/content/drive/MyDrive/Colab Notebooks/veritabani.txt"

print("***Kütüphane Kataloğuna Hoşgeldiniz.***")
print("Menüden seçeneklerden bir tanesini seçerek işleminizi gerçekleştirebilirsiniz.")
def kayıtlarListeleme():
  dosya = open(dosyaGidis, "r")
  for line in dosya.readlines():
    print(line)
    dosya.close()

def yeniKayitEkle():
  kitapAdı = input("Kitap adı giriniz: ")
  yazarAdı = input("Yazar adı giriniz: ")
  basımYılı = input("Basım yılını giriniz: ")
  yayınEvı = input("Yayınevini giriniz: ")
  dosya = open(dosyaGidis, "a") #mevcut veriye ek veri yazılması için parametre "a"
  dosya.write(kitapAdı + " - "+ yazarAdı + " - " + basımYılı + " - " + yayınEvı + " - " + "\n")  
  dosya.close()
  print("\n" + "Kitap ekleme işlemi gerçekleşmiştir" + "\n")
  menu()

  
def kayitAra():
  dosya = open(dosyaGidis)
  arananKitap = input("Aradığınız kitabın adını giriniz: ")
  dosya = open(dosyaGidis, "r")
  arananKitaplar = dosya.read().find(arananKitap)
  if arananKitaplar:
    print("Aradığınız kitap mevcut.")
  elif arananKitaplar:
    print("Aradığınız kitap bulunmamaktadır.")


def menu():
  while True:
    menuSecim = input("\n---------------------- \n Yapmak istediğiniz işlemi giriniz. \n 1)Kayıtları Listele \n 2)Yeni kayıt ekle \n 3)Kayıt ara \n 4)Çıkış \n")
    
    if menuSecim == "1":
      print("Kayıtları Listele")
      kayıtlarListeleme()
    
    elif menuSecim == "2":
      print("Yeni kayıt ekle")
      yeniKayitEkle()

    elif menuSecim == "3":
      print("Kayıt Ara")
      kayitAra()

    elif menuSecim == "4":
      print("Çıkış Yapıldı")
      break
    else:
      ("\n---------------------- \n Yapmak istediğiniz işlemi giriniz. \n 1)Kayıtları Listele \n 2)Yeni kayıt ekle \n 3)Kayıt ara \n 4)Çıkış \n")
          

menu()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ***Kütüphane Kataloğuna Hoşgeldiniz.***
# Menüden seçeneklerden bir tanesini seçerek işleminizi gerçekleştirebilirsiniz.
#
# ----------------------
#  Yapmak istediğiniz işlemi giriniz.
#  1)Kayıtları Listele
#  2)Yeni kayıt ekle
#  3)Kayıt ara
#  4)Çıkış
# 1
# Kayıtları Listele
# Sırça Köşk - Sabahattin Ali - 2021 - Yapı Kredi Yayınları
#
# Yorgun Savaşçı - Kemal Tahir - 2016 - İthaki Yayınları
#
# İnsan Ne İle Yaşar - Lev Tolstoy - 2021 - Mekika Yayınları
#
# Zeytindağı - Falih Rıfkı Atay - 2021 - Pozitif Yayınları
#
# Kuyucaklı Yusuf - Sabahttin Ali - 2021 - Can Modern Yayınları
#
# 1984 - George Orwell - 2021 - Türkiye İş Bankası Kültür Yayınları -
#
#
# ----------------------
#  Yapmak istediğiniz işlemi giriniz.
#  1)Kayıtları Listele
#  2)Yeni kayıt ekle
#  3)Kayıt ara
#  4)Çıkış
# 2
# Yeni kayıt ekle
# Kitap adı giriniz: Beyaz Geceler
# ...

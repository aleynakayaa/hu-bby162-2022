# %% [markdown]
# <a href="https://colab.research.google.com/github/aleynakayaa/hu-bby162-2022/blob/main/Proje002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import choice
 
kelimeler=[" ", " ", " ", " "]


def Basitseviye():
   print("Basit seviye seçildi")
def OrtaSeviye():
   print("Orta seviye seçildi")
def Ileriseviye():
   print("İleri seviye seçildi")
   

def menu():
    fonksiyonListesi=[Basitseviye, OrtaSeviye, Ileriseviye]
    while True:
        print("1-Basit seviye")
        print("2-Orta seviye")
        print("3-İleri seviye")
        
        seciminiz=int(input("Lütfen oynamak istediğiniz seviyeyi seçiniz.(0-3): "))
        if seciminiz==1:
           print("Basit seviyeden başlayacaksınız")
           
           adamCan = 10

        kelimeler = ["ece", "elif", "gül", "mine"]
        secilenKelime = choice(kelimeler)
        print(secilenKelime)
        dizilenKelime = [] 
        for diz in secilenKelime:
            dizilenKelime.append("_")
        print(dizilenKelime)

        while adamCan > 0:
              
              girilenHarf = input("Bir harf giriniz: ")
              canKontrol = girilenHarf in secilenKelime
              if canKontrol == False:
                 adamCan-=1
              i = 0
              for kontrol in secilenKelime:
                if secilenKelime[i] == girilenHarf:
                  dizilenKelime[i] = girilenHarf
                i+=1
              print(dizilenKelime)
              print("Kalan can: "+ str(adamCan))
              
          

        if seciminiz==2:
            print("Orta seviden başlayacaksınız")

            adamCan = 5

        kelimeler = ["karınca", "papağan", "örümcek"]
        secilenKelime = choice(kelimeler)
        print(secilenKelime)
        dizilenKelime = []
        for diz in secilenKelime:
          dizilenKelime.append("_")
        print(dizilenKelime)

        while adamCan > 0:
           girilenHarf = input("Bir harf giriniz: ")
           canKontrol = girilenHarf in secilenKelime
           if canKontrol == False:
             adamCan-=1
           i = 0
           for kontrol in secilenKelime:
             if secilenKelime[i] == girilenHarf:
               dizilenKelime[i] = girilenHarf
             i+=1
           print(dizilenKelime)
           print("Kalan can: "+ str(adamCan))

        
        if seciminiz==3:
            print("İleri seviyeden başlayacaksınız")

            adamCan = 3

        kelimeler = ["tahterevalli", "röpdoşambr", "abdestbozan", "dilimlemek"]
        secilenKelime = choice(kelimeler)
        print(secilenKelime)
        dizilenKelime = []
        for diz in secilenKelime:
            dizilenKelime.append("_")
        print(dizilenKelime)

        while adamCan > 0:
           girilenHarf = input("Bir harf giriniz: ")
           canKontrol = girilenHarf in secilenKelime
           if canKontrol == False:
            adamCan-=1
           i = 0
           for kontrol in secilenKelime:
             if secilenKelime[i] == girilenHarf:
               dizilenKelime[i] = girilenHarf
             i+=1
           print(dizilenKelime)
           print("Kalan can: "+ str(adamCan))
           break
           print("Maalesef, Kaybettiniz!)
           
           
           fonksiyonListesi[seciminiz-1]

       

menu()
# Out:
# 1-Basit seviye
# 2-Orta seviye
# 3-İleri seviye
# Basit seviyeden başlayacaksınız
# elif
# ['_', '_', '_', '_']
# ['_', 'l', '_', '_']
# Kalan can: 10
# ['_', 'l', '_', '_']
# Kalan can: 9
# ['_', 'l', '_', '_']
# Kalan can: 8
# ['_', 'l', '_', '_']
# Kalan can: 7
# ['e', 'l', '_', '_']
# Kalan can: 7
# ['e', 'l', '_', '_']
# Kalan can: 7
# ['e', 'l', '_', '_']
# Kalan can: 6
# ['e', 'l', '_', 'f']
# Kalan can: 6
# ['e', 'l', '_', 'f']
# Kalan can: 5
# ['e', 'l', '_', 'f']
# Kalan can: 4
# ['e', 'l', '_', 'f']
# Kalan can: 3
# ['e', 'l', '_', 'f']
# Kalan can: 2
# ['e', 'l', '_', 'f']
# Kalan can: 1
# ['e', 'l', '_', 'f']
# Kalan can: 0
# papağan
# ['_', '_', '_', '_', '_', '_', '_']
# tahterevalli
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# 1-Basit seviye
# 2-Orta seviye
# 3-İleri seviye
# Lütfen oynamak istediğiniz seviyeyi seçiniz.(0-3): 3
# elif
# ['_', '_', '_', '_']
# karınca
# ['_', '_', '_', '_', '_', '_', '_']
# İleri seviyeden başlayacaksınız
# tahterevalli
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_']

# %% [markdown]
# <a href="https://colab.research.google.com/github/aleynakayaa/hu-bby162-2022/blob/main/Proje02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import choice


def Basitseviye(): 
   print("Basit seviye seçildi")
def OrtaSeviye(): 
   print("Orta seviye seçildi")
def Ileriseviye(): 
   print("İleri seviye seçildi")
   

def menu():
    fonksiyonListesi=[Basitseviye, OrtaSeviye, Ileriseviye]
    while True:
        print("1-Basit seviye")
        print("2-Orta seviye")
        print("3-İleri seviye")
        
        seciminiz=int(input("Lütfen oynamak istediğiniz seviyeyi seçiniz.(1-3): "))
        if seciminiz==1:
           print("Basit seviyeden başlayacaksınız")
           
           adamCan = 2

        kelimeler = ["ece", "elif", "gül", "mine"]
        secilenKelime = choice(kelimeler)
        dizilenKelime = [] 
        for diz in secilenKelime:
            dizilenKelime.append("_")
        print(dizilenKelime)

        while adamCan > 0:
              
              girilenHarf = input("Bir harf giriniz: ")
              canKontrol = girilenHarf in secilenKelime
              if canKontrol == False:
                 adamCan-=1
              i = 0
              for kontrol in secilenKelime:
                if secilenKelime[i] == girilenHarf:
                  dizilenKelime[i] = girilenHarf
                i+=1
              print(dizilenKelime)
              print("Kalan can: "+ str(adamCan))
              if adamCan ==0:
                print("Basit seviyeyi geçemediniz")
              
            
                 
        

        if seciminiz==2:
            print("Orta seviden başlayacaksınız")

            adamCan = 5

        kelimeler = ["karınca", "papağan", "örümcek"]
        secilenKelime = choice(kelimeler)
        dizilenKelime = []
        for diz in secilenKelime:
          dizilenKelime.append("_")
        print(dizilenKelime)

        while adamCan > 0:
           girilenHarf = input("Bir harf giriniz: ")
           canKontrol = girilenHarf in secilenKelime
           if canKontrol == False:
             adamCan-=1
           i = 0
           for kontrol in secilenKelime:
             if secilenKelime[i] == girilenHarf:
               dizilenKelime[i] = girilenHarf
             i+=1
           print(dizilenKelime)
           print("Kalan can: "+ str(adamCan))
           if adamCan ==0:
                print("Orta seviyeyi geçemediniz")


        
        if seciminiz==3:
            print("İleri seviyeden başlayacaksınız")

            adamCan = 3

        kelimeler = ["tahterevalli", "röpdoşambr", "abdestbozan", "dilimlemek"]
        secilenKelime = choice(kelimeler)
        dizilenKelime = []
        for diz in secilenKelime:
            dizilenKelime.append("_")
        print(dizilenKelime)

        while adamCan > 0:
           girilenHarf = input("Bir harf giriniz: ")
           canKontrol = girilenHarf in secilenKelime
           if canKontrol == False:
            adamCan-=1
           i = 0
           for kontrol in secilenKelime:
             if secilenKelime[i] == girilenHarf:
               dizilenKelime[i] = girilenHarf
             i+=1
           print(dizilenKelime)
           print("Kalan can: "+ str(adamCan))
           if adamCan ==0:
                print("İeri seviyeyide geçemediniz")
                break
                print("Bir daha oynamayınız.")
           
           
           
      

       

menu()
# Out:
# 1-Basit seviye
# 2-Orta seviye
# 3-İleri seviye
# Lütfen oynamak istediğiniz seviyeyi seçiniz.(1-3): 1
# Basit seviyeden başlayacaksınız
# ['_', '_', '_', '_']
